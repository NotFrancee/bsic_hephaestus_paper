# %%
import pandas as pd 
import numpy as np 
from fractional_differentiation import find_stat_series
import itertools
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# # Get the two datasets

# %%
data_non_stat = pd.read_csv('../../data/dataset_non_stat.csv')

# %%
data_non_stat.columns
# Out:
# Index(['date', 'permno', 'CAPEI', 'bm', 'evm', 'pe_op_basic', 'pe_op_dil',
#        'pe_exi', 'pe_inc', 'ps', 'pcf', 'dpr', 'npm', 'opmbd', 'opmad', 'gpm',
#        'ptpm', 'cfm', 'roa', 'roe', 'roce', 'efftax', 'aftret_eq',
#        'aftret_invcapx', 'aftret_equity', 'pretret_noa', 'pretret_earnat',
#        'GProf', 'equity_invcap', 'debt_invcap', 'totdebt_invcap',
#        'capital_ratio', 'int_debt', 'int_totdebt', 'cash_lt', 'invt_act',
#        'rect_act', 'debt_at', 'debt_ebitda', 'short_debt', 'curr_debt',
#        'lt_debt', 'profit_lct', 'ocf_lct', 'cash_debt', 'fcf_ocf', 'lt_ppent',
#        'dltt_be', 'debt_assets', 'debt_capital', 'de_ratio', 'intcov',
#        'intcov_ratio', 'cash_ratio', 'quick_ratio', 'curr_ratio', 'inv_turn',
#        'at_turn', 'rect_turn', 'pay_turn', 'sale_invcap', 'sale_equity',
#        'rd_sale', 'adv_sale', 'staff_sale', 'accrual', 'ptb', 'prc', 'vol',
#        'ret', 'retx', 'mktcap', 'prc_adj', 'naics_processed',
#        'ret_industry_tot', 'ret_industry_relative', 'MACD_index', 'rsi',
#        '12_month_return', '3_month_return', 'divyield'],
#       dtype='object')

# %%
data_stat = pd.read_csv('../../data/datasetlabel.csv')

# %% [markdown]
# Get the columns that are missing from the stationarized dataset

# %%
missing_cols = set(data_non_stat.columns).difference(set(data_stat.columns))
data_to_stationarize = data_non_stat[['permno', 'date'] + list(missing_cols)]

data_to_stationarize.head()
# Out:
#    permno        date  profit_lct  curr_ratio  intcov_ratio  pretret_earnat  \
# 0   10078  2000-02-01       0.988       2.071      2433.280           0.306
# 1   85072  2000-02-01       0.884       2.056        77.617           0.258
# 2   70536  2000-02-01       2.043       5.658       263.685           0.172
# 3   16432  2000-02-01       0.202       1.342         3.563           0.066
# 4   85035  2000-02-01       2.111       5.174        11.032           0.262
#
#    inv_turn  int_totdebt  12_month_return  efftax  ...    intcov  ocf_lct  \
# 0    18.324        0.028              NaN   0.358  ...  1528.900    0.868
# 1     2.409        0.034              NaN   0.407  ...    33.820    0.227
# 2     0.914        0.047              NaN   0.314  ...   181.812    1.673
# 3     4.769        0.065              NaN   0.276  ...     2.979    0.271
# 4     4.208        0.133              NaN   0.200  ...    10.073    0.735
#
#    int_debt  quick_ratio  rect_act  invt_act    dpr  pretret_noa  cash_ratio  \
# 0       NaN        1.951     0.368     0.058  0.000        0.509       0.900
# 1     0.125        0.854     0.237     0.585  0.000        0.395       0.114
# 2     1.903        2.452     0.304     0.567  0.188        0.192       0.345
# 3     0.114        0.745     0.435     0.445  0.572        0.106       0.067
# 4     0.172        4.163     0.180     0.195  0.000        0.307       3.197
#
#    curr_debt
# 0      0.811
# 1      0.748
# 2      0.693
# 3      0.500
# 4      0.694
#
# [5 rows x 21 columns]

# %%
len(missing_cols)
# Out:
# 19

# %% [markdown]
# # Stationarize the subset of columns

# %%
missing_data_stationary = data_to_stationarize.copy()

diffs = np.linspace(0.05, 1, 40)

missing_data_stationary.shape
# Out:
# (3484790, 21)

# %%
from ipywidgets import IntProgress
from IPython.display import display

permnos = missing_data_stationary.index
features = missing_data_stationary.columns.drop(['date', 'permno'])
print(features)
# just to display progress
f = IntProgress(min=0, max=np.prod([len(features), len(permnos)]))
display(f)

# iterate through all permnos and features
for permno, feature in itertools.product(permnos, features):
    f.value += 1

    # select the data relative to the permno and feature
    mask = data_to_stationarize["permno"] == permno
    data = data_to_stationarize.loc[mask, [feature]]
    original_index = data.index
    data = data.dropna()

    # handle features which are empty
    if data.empty:
        print(f"there is no data for {permno} - {feature}")
        continue

    if np.max(data) - np.min(data) < 1e-6:
        print(f"there is no variation in {permno} - {feature}")
        continue

    print(permno, feature)
    print("-----")
    # check if the series is stationary
    try:
        if adfuller(data, regression="ct")[1] > 0.01:
            stat_series = find_stat_series(data, diffs=diffs)
            stat_series = stat_series.reindex(original_index)
            missing_data_stationary.loc[mask, feature] = stat_series.values

    except Exception as e:
        print(f"error in {permno} - {feature}")
        print(e)
        continue
# Out:
# Index(['profit_lct', 'curr_ratio', 'intcov_ratio', 'pretret_earnat',
#        'inv_turn', 'int_totdebt', '12_month_return', 'efftax',
#        '3_month_return', 'intcov', 'ocf_lct', 'int_debt', 'quick_ratio',
#        'rect_act', 'invt_act', 'dpr', 'pretret_noa', 'cash_ratio',
#        'curr_debt'],
#       dtype='object')
# IntProgress(value=0, max=66211010)
# there is no data for 0 - profit_lct
# there is no data for 0 - curr_ratio
# there is no data for 0 - intcov_ratio
# there is no data for 0 - pretret_earnat
# there is no data for 0 - inv_turn
# there is no data for 0 - int_totdebt
# there is no data for 0 - 12_month_return
# there is no data for 0 - efftax
# there is no data for 0 - 3_month_return
# there is no data for 0 - intcov
# there is no data for 0 - ocf_lct
# there is no data for 0 - int_debt
# there is no data for 0 - quick_ratio
# there is no data for 0 - rect_act
# there is no data for 0 - invt_act
# there is no data for 0 - dpr
# there is no data for 0 - pretret_noa
# there is no data for 0 - cash_ratio
# there is no data for 0 - curr_debt
# there is no data for 1 - profit_lct
# there is no data for 1 - curr_ratio
# there is no data for 1 - intcov_ratio
# there is no data for 1 - pretret_earnat
# there is no data for 1 - inv_turn
# there is no data for 1 - int_totdebt
# there is no data for 1 - 12_month_return
# there is no data for 1 - efftax
# there is no data for 1 - 3_month_return
# there is no data for 1 - intcov
# there is no data for 1 - ocf_lct
# there is no data for 1 - int_debt
# there is no data for 1 - quick_ratio
# there is no data for 1 - rect_act
# there is no data for 1 - invt_act
# there is no data for 1 - dpr
# there is no data for 1 - pretret_noa
# there is no data for 1 - cash_ratio
# there is no data for 1 - curr_debt
# there is no data for 2 - profit_lct
# there is no data for 2 - curr_ratio
# there is no data for 2 - intcov_ratio
# there is no data for 2 - pretret_earnat
# there is no data for 2 - inv_turn
# there is no data for 2 - int_totdebt
# there is no data for 2 - 12_month_return
# there is no data for 2 - efftax
# there is no data for 2 - 3_month_return
# there is no data for 2 - intcov
# there is no data for 2 - ocf_lct
# there is no data for 2 - int_debt
# there is no data for 2 - quick_ratio
# there is no data for 2 - rect_act
# there is no data for 2 - invt_act
# there is no data for 2 - dpr
# there is no data for 2 - pretret_noa
# there is no data for 2 - cash_ratio
# there is no data for 2 - curr_debt
# there is no data for 3 - profit_lct
# there is no data for 3 - curr_ratio
# there is no data for 3 - intcov_ratio
# there is no data for 3 - pretret_earnat
# there is no data for 3 - inv_turn
# there is no data for 3 - int_totdebt
# there is no data for 3 - 12_month_return
# there is no data for 3 - efftax
# there is no data for 3 - 3_month_return
# there is no data for 3 - intcov
# there is no data for 3 - ocf_lct
# there is no data for 3 - int_debt
# there is no data for 3 - quick_ratio
# there is no data for 3 - rect_act
# there is no data for 3 - invt_act
# there is no data for 3 - dpr
# there is no data for 3 - pretret_noa
# there is no data for 3 - cash_ratio
# there is no data for 3 - curr_debt
# there is no data for 4 - profit_lct
# there is no data for 4 - curr_ratio
# there is no data for 4 - intcov_ratio
# there is no data for 4 - pretret_earnat
# there is no data for 4 - inv_turn
# there is no data for 4 - int_totdebt
# there is no data for 4 - 12_month_return
# there is no data for 4 - efftax
# there is no data for 4 - 3_month_return
# there is no data for 4 - intcov
# there is no data for 4 - ocf_lct
# there is no data for 4 - int_debt
# there is no data for 4 - quick_ratio
# there is no data for 4 - rect_act
# there is no data for 4 - invt_act
# there is no data for 4 - dpr
# there is no data for 4 - pretret_noa
# there is no data for 4 - cash_ratio
# there is no data for 4 - curr_debt
# there is no data for 5 - profit_lct
# there is no data for 5 - curr_ratio
# there is no data for 5 - intcov_ratio
# there is no data for 5 - pretret_earnat
# there is no data for 5 - inv_turn
# there is no data for 5 - int_totdebt
# there is no data for 5 - 12_month_return
# there is no data for 5 - efftax
# there is no data for 5 - 3_month_return
# there is no data for 5 - intcov
# there is no data for 5 - ocf_lct
# there is no data for 5 - int_debt
# there is no data for 5 - quick_ratio
# there is no data for 5 - rect_act
# there is no data for 5 - invt_act
# there is no data for 5 - dpr
# there is no data for 5 - pretret_noa
# there is no data for 5 - cash_ratio
# there is no data for 5 - curr_debt
# there is no data for 6 - profit_lct
# there is no data for 6 - curr_ratio
# there is no data for 6 - intcov_ratio
# there is no data for 6 - pretret_earnat
# there is no data for 6 - inv_turn
# there is no data for 6 - int_totdebt
# there is no data for 6 - 12_month_return
# there is no data for 6 - efftax
# there is no data for 6 - 3_month_return
# there is no data for 6 - intcov
# there is no data for 6 - ocf_lct
# there is no data for 6 - int_debt
# there is no data for 6 - quick_ratio
# there is no data for 6 - rect_act
# there is no data for 6 - invt_act
# there is no data for 6 - dpr
# there is no data for 6 - pretret_noa
# there is no data for 6 - cash_ratio
# there is no data for 6 - curr_debt
# there is no data for 7 - profit_lct
# there is no data for 7 - curr_ratio
# there is no data for 7 - intcov_ratio
# there is no data for 7 - pretret_earnat
# there is no data for 7 - inv_turn
# there is no data for 7 - int_totdebt
# there is no data for 7 - 12_month_return
# there is no data for 7 - efftax
# there is no data for 7 - 3_month_return
# there is no data for 7 - intcov
# there is no data for 7 - ocf_lct
# there is no data for 7 - int_debt
# there is no data for 7 - quick_ratio
# there is no data for 7 - rect_act
# there is no data for 7 - invt_act
# there is no data for 7 - dpr
# there is no data for 7 - pretret_noa
# there is no data for 7 - cash_ratio
# there is no data for 7 - curr_debt
# there is no data for 8 - profit_lct
# there is no data for 8 - curr_ratio
# there is no data for 8 - intcov_ratio
# there is no data for 8 - pretret_earnat
# there is no data for 8 - inv_turn
# there is no data for 8 - int_totdebt
# there is no data for 8 - 12_month_return
# there is no data for 8 - efftax
# there is no data for 8 - 3_month_return
# there is no data for 8 - intcov
# there is no data for 8 - ocf_lct
# there is no data for 8 - int_debt
# there is no data for 8 - quick_ratio
# there is no data for 8 - rect_act
# there is no data for 8 - invt_act
# there is no data for 8 - dpr
# there is no data for 8 - pretret_noa
# there is no data for 8 - cash_ratio
# there is no data for 8 - curr_debt
# there is no data for 9 - profit_lct
# there is no data for 9 - curr_ratio
# there is no data for 9 - intcov_ratio
# there is no data for 9 - pretret_earnat
# there is no data for 9 - inv_turn
# there is no data for 9 - int_totdebt
# there is no data for 9 - 12_month_return
# there is no data for 9 - efftax
# there is no data for 9 - 3_month_return
# there is no data for 9 - intcov
# there is no data for 9 - ocf_lct
# there is no data for 9 - int_debt
# there is no data for 9 - quick_ratio
# there is no data for 9 - rect_act
# there is no data for 9 - invt_act
# there is no data for 9 - dpr
# there is no data for 9 - pretret_noa
# there is no data for 9 - cash_ratio
# there is no data for 9 - curr_debt
# there is no data for 10 - profit_lct
# there is no data for 10 - curr_ratio
# there is no data for 10 - intcov_ratio
# there is no data for 10 - pretret_earnat
# there is no data for 10 - inv_turn
# there is no data for 10 - int_totdebt
# there is no data for 10 - 12_month_return
# there is no data for 10 - efftax
# there is no data for 10 - 3_month_return
# there is no data for 10 - intcov
# there is no data for 10 - ocf_lct
# there is no data for 10 - int_debt
# there is no data for 10 - quick_ratio
# there is no data for 10 - rect_act
# there is no data for 10 - invt_act
# there is no data for 10 - dpr
# there is no data for 10 - pretret_noa
# there is no data for 10 - cash_ratio
# there is no data for 10 - curr_debt
# there is no data for 11 - profit_lct
# there is no data for 11 - curr_ratio
# there is no data for 11 - intcov_ratio
# there is no data for 11 - pretret_earnat
# there is no data for 11 - inv_turn
# there is no data for 11 - int_totdebt
# there is no data for 11 - 12_month_return
# there is no data for 11 - efftax
# there is no data for 11 - 3_month_return
# there is no data for 11 - intcov
# there is no data for 11 - ocf_lct
# there is no data for 11 - int_debt
# there is no data for 11 - quick_ratio
# there is no data for 11 - rect_act
# there is no data for 11 - invt_act
# there is no data for 11 - dpr
# there is no data for 11 - pretret_noa
# there is no data for 11 - cash_ratio
# there is no data for 11 - curr_debt
# there is no data for 12 - profit_lct
# there is no data for 12 - curr_ratio
# there is no data for 12 - intcov_ratio
# there is no data for 12 - pretret_earnat
# there is no data for 12 - inv_turn
# there is no data for 12 - int_totdebt
# there is no data for 12 - 12_month_return
# there is no data for 12 - efftax
# there is no data for 12 - 3_month_return
# there is no data for 12 - intcov
# there is no data for 12 - ocf_lct
# there is no data for 12 - int_debt
# there is no data for 12 - quick_ratio
# there is no data for 12 - rect_act
# there is no data for 12 - invt_act
# there is no data for 12 - dpr
# there is no data for 12 - pretret_noa
# there is no data for 12 - cash_ratio
# there is no data for 12 - curr_debt
# there is no data for 13 - profit_lct
# there is no data for 13 - curr_ratio
# there is no data for 13 - intcov_ratio
# there is no data for 13 - pretret_earnat
# there is no data for 13 - inv_turn
# there is no data for 13 - int_totdebt
# there is no data for 13 - 12_month_return
# there is no data for 13 - efftax
# there is no data for 13 - 3_month_return
# there is no data for 13 - intcov
# there is no data for 13 - ocf_lct
# there is no data for 13 - int_debt
# there is no data for 13 - quick_ratio
# there is no data for 13 - rect_act
# there is no data for 13 - invt_act
# there is no data for 13 - dpr
# there is no data for 13 - pretret_noa
# there is no data for 13 - cash_ratio
# there is no data for 13 - curr_debt
# there is no data for 14 - profit_lct
# there is no data for 14 - curr_ratio
# there is no data for 14 - intcov_ratio
# there is no data for 14 - pretret_earnat
# there is no data for 14 - inv_turn
# there is no data for 14 - int_totdebt
# there is no data for 14 - 12_month_return
# there is no data for 14 - efftax
# there is no data for 14 - 3_month_return
# there is no data for 14 - intcov
# there is no data for 14 - ocf_lct
# there is no data for 14 - int_debt
# there is no data for 14 - quick_ratio
# there is no data for 14 - rect_act
# there is no data for 14 - invt_act
# there is no data for 14 - dpr
# there is no data for 14 - pretret_noa
# there is no data for 14 - cash_ratio
# there is no data for 14 - curr_debt
# there is no data for 15 - profit_lct
# there is no data for 15 - curr_ratio
# there is no data for 15 - intcov_ratio
# there is no data for 15 - pretret_earnat
# there is no data for 15 - inv_turn
# there is no data for 15 - int_totdebt
# there is no data for 15 - 12_month_return
# there is no data for 15 - efftax
# there is no data for 15 - 3_month_return
# there is no data for 15 - intcov
# there is no data for 15 - ocf_lct
# there is no data for 15 - int_debt
# there is no data for 15 - quick_ratio
# there is no data for 15 - rect_act
# there is no data for 15 - invt_act
# there is no data for 15 - dpr
# there is no data for 15 - pretret_noa
# there is no data for 15 - cash_ratio
# there is no data for 15 - curr_debt
# there is no data for 16 - profit_lct
# there is no data for 16 - curr_ratio
# there is no data for 16 - intcov_ratio
# there is no data for 16 - pretret_earnat
# there is no data for 16 - inv_turn
# there is no data for 16 - int_totdebt
# there is no data for 16 - 12_month_return
# there is no data for 16 - efftax
# there is no data for 16 - 3_month_return
# there is no data for 16 - intcov
# there is no data for 16 - ocf_lct
# there is no data for 16 - int_debt
# there is no data for 16 - quick_ratio
# there is no data for 16 - rect_act
# there is no data for 16 - invt_act
# there is no data for 16 - dpr
# there is no data for 16 - pretret_noa
# there is no data for 16 - cash_ratio
# there is no data for 16 - curr_debt
# there is no data for 17 - profit_lct
# there is no data for 17 - curr_ratio
# there is no data for 17 - intcov_ratio
# there is no data for 17 - pretret_earnat
# there is no data for 17 - inv_turn
# there is no data for 17 - int_totdebt
# there is no data for 17 - 12_month_return
# there is no data for 17 - efftax
# there is no data for 17 - 3_month_return
# there is no data for 17 - intcov
# there is no data for 17 - ocf_lct
# there is no data for 17 - int_debt
# there is no data for 17 - quick_ratio
# there is no data for 17 - rect_act
# there is no data for 17 - invt_act
# there is no data for 17 - dpr
# there is no data for 17 - pretret_noa
# there is no data for 17 - cash_ratio
# there is no data for 17 - curr_debt
# there is no data for 18 - profit_lct
# there is no data for 18 - curr_ratio
# there is no data for 18 - intcov_ratio
# there is no data for 18 - pretret_earnat
# there is no data for 18 - inv_turn
# there is no data for 18 - int_totdebt
# there is no data for 18 - 12_month_return
# there is no data for 18 - efftax
# there is no data for 18 - 3_month_return
# there is no data for 18 - intcov
# there is no data for 18 - ocf_lct
# there is no data for 18 - int_debt
# there is no data for 18 - quick_ratio
# there is no data for 18 - rect_act
# there is no data for 18 - invt_act
# there is no data for 18 - dpr
# there is no data for 18 - pretret_noa
# there is no data for 18 - cash_ratio
# there is no data for 18 - curr_debt
# there is no data for 19 - profit_lct
# there is no data for 19 - curr_ratio
# there is no data for 19 - intcov_ratio
# there is no data for 19 - pretret_earnat
# there is no data for 19 - inv_turn
# there is no data for 19 - int_totdebt
# there is no data for 19 - 12_month_return
# there is no data for 19 - efftax
# there is no data for 19 - 3_month_return
# there is no data for 19 - intcov
# there is no data for 19 - ocf_lct
# there is no data for 19 - int_debt
# there is no data for 19 - quick_ratio
# there is no data for 19 - rect_act
# there is no data for 19 - invt_act
# there is no data for 19 - dpr
# there is no data for 19 - pretret_noa
# there is no data for 19 - cash_ratio
# there is no data for 19 - curr_debt
# there is no data for 20 - profit_lct
# there is no data for 20 - curr_ratio
# there is no data for 20 - intcov_ratio
# there is no data for 20 - pretret_earnat
# there is no data for 20 - inv_turn
# there is no data for 20 - int_totdebt
# there is no data for 20 - 12_month_return
# there is no data for 20 - efftax
# there is no data for 20 - 3_month_return
# there is no data for 20 - intcov
# there is no data for 20 - ocf_lct
# there is no data for 20 - int_debt
# there is no data for 20 - quick_ratio
# there is no data for 20 - rect_act
# there is no data for 20 - invt_act
# there is no data for 20 - dpr
# there is no data for 20 - pretret_noa
# there is no data for 20 - cash_ratio
# there is no data for 20 - curr_debt
# there is no data for 21 - profit_lct
# there is no data for 21 - curr_ratio
# there is no data for 21 - intcov_ratio
# there is no data for 21 - pretret_earnat
# there is no data for 21 - inv_turn
# there is no data for 21 - int_totdebt
# there is no data for 21 - 12_month_return
# there is no data for 21 - efftax
# there is no data for 21 - 3_month_return
# there is no data for 21 - intcov
# there is no data for 21 - ocf_lct
# there is no data for 21 - int_debt
# there is no data for 21 - quick_ratio
# there is no data for 21 - rect_act
# there is no data for 21 - invt_act
# there is no data for 21 - dpr
# there is no data for 21 - pretret_noa
# there is no data for 21 - cash_ratio
# there is no data for 21 - curr_debt
# there is no data for 22 - profit_lct
# there is no data for 22 - curr_ratio
# there is no data for 22 - intcov_ratio
# there is no data for 22 - pretret_earnat
# there is no data for 22 - inv_turn
# there is no data for 22 - int_totdebt
# there is no data for 22 - 12_month_return
# there is no data for 22 - efftax
# there is no data for 22 - 3_month_return
# there is no data for 22 - intcov
# there is no data for 22 - ocf_lct
# there is no data for 22 - int_debt
# there is no data for 22 - quick_ratio
# there is no data for 22 - rect_act
# there is no data for 22 - invt_act
# there is no data for 22 - dpr
# there is no data for 22 - pretret_noa
# there is no data for 22 - cash_ratio
# there is no data for 22 - curr_debt
# there is no data for 23 - profit_lct
# there is no data for 23 - curr_ratio
# there is no data for 23 - intcov_ratio
# there is no data for 23 - pretret_earnat
# there is no data for 23 - inv_turn
# there is no data for 23 - int_totdebt
# there is no data for 23 - 12_month_return
# there is no data for 23 - efftax
# there is no data for 23 - 3_month_return
# there is no data for 23 - intcov
# there is no data for 23 - ocf_lct
# there is no data for 23 - int_debt
# there is no data for 23 - quick_ratio
# there is no data for 23 - rect_act
# there is no data for 23 - invt_act
# there is no data for 23 - dpr
# there is no data for 23 - pretret_noa
# there is no data for 23 - cash_ratio
# there is no data for 23 - curr_debt
# there is no data for 24 - profit_lct
# there is no data for 24 - curr_ratio
# there is no data for 24 - intcov_ratio
# there is no data for 24 - pretret_earnat
# there is no data for 24 - inv_turn
# there is no data for 24 - int_totdebt
# there is no data for 24 - 12_month_return
# there is no data for 24 - efftax
# there is no data for 24 - 3_month_return
# there is no data for 24 - intcov
# there is no data for 24 - ocf_lct
# there is no data for 24 - int_debt
# there is no data for 24 - quick_ratio
# there is no data for 24 - rect_act
# there is no data for 24 - invt_act
# there is no data for 24 - dpr
# there is no data for 24 - pretret_noa
# there is no data for 24 - cash_ratio
# there is no data for 24 - curr_debt
# there is no data for 25 - profit_lct
# there is no data for 25 - curr_ratio
# there is no data for 25 - intcov_ratio
# there is no data for 25 - pretret_earnat
# there is no data for 25 - inv_turn
# there is no data for 25 - int_totdebt
# there is no data for 25 - 12_month_return
# there is no data for 25 - efftax
# there is no data for 25 - 3_month_return
# there is no data for 25 - intcov
# there is no data for 25 - ocf_lct
# there is no data for 25 - int_debt
# there is no data for 25 - quick_ratio
# there is no data for 25 - rect_act
# there is no data for 25 - invt_act
# there is no data for 25 - dpr
# there is no data for 25 - pretret_noa
# there is no data for 25 - cash_ratio
# there is no data for 25 - curr_debt
# there is no data for 26 - profit_lct
# there is no data for 26 - curr_ratio
# there is no data for 26 - intcov_ratio
# there is no data for 26 - pretret_earnat
# there is no data for 26 - inv_turn
# there is no data for 26 - int_totdebt
# there is no data for 26 - 12_month_return
# there is no data for 26 - efftax
# there is no data for 26 - 3_month_return
# there is no data for 26 - intcov
# there is no data for 26 - ocf_lct
# there is no data for 26 - int_debt
# there is no data for 26 - quick_ratio
# there is no data for 26 - rect_act
# there is no data for 26 - invt_act
# there is no data for 26 - dpr
# there is no data for 26 - pretret_noa
# there is no data for 26 - cash_ratio
# there is no data for 26 - curr_debt
# there is no data for 27 - profit_lct
# there is no data for 27 - curr_ratio
# there is no data for 27 - intcov_ratio
# there is no data for 27 - pretret_earnat
# there is no data for 27 - inv_turn
# there is no data for 27 - int_totdebt
# there is no data for 27 - 12_month_return
# there is no data for 27 - efftax
# there is no data for 27 - 3_month_return
# there is no data for 27 - intcov
# there is no data for 27 - ocf_lct
# there is no data for 27 - int_debt
# there is no data for 27 - quick_ratio
# there is no data for 27 - rect_act
# there is no data for 27 - invt_act
# there is no data for 27 - dpr
# there is no data for 27 - pretret_noa
# there is no data for 27 - cash_ratio
# there is no data for 27 - curr_debt
# there is no data for 28 - profit_lct
# there is no data for 28 - curr_ratio
# there is no data for 28 - intcov_ratio
# there is no data for 28 - pretret_earnat
# there is no data for 28 - inv_turn
# there is no data for 28 - int_totdebt
# there is no data for 28 - 12_month_return
# there is no data for 28 - efftax
# there is no data for 28 - 3_month_return
# there is no data for 28 - intcov
# there is no data for 28 - ocf_lct
# there is no data for 28 - int_debt
# there is no data for 28 - quick_ratio
# there is no data for 28 - rect_act
# there is no data for 28 - invt_act
# there is no data for 28 - dpr
# there is no data for 28 - pretret_noa
# there is no data for 28 - cash_ratio
# there is no data for 28 - curr_debt
# there is no data for 29 - profit_lct
# there is no data for 29 - curr_ratio
# there is no data for 29 - intcov_ratio
# there is no data for 29 - pretret_earnat
# there is no data for 29 - inv_turn
# there is no data for 29 - int_totdebt
# there is no data for 29 - 12_month_return
# there is no data for 29 - efftax
# there is no data for 29 - 3_month_return
# there is no data for 29 - intcov
# there is no data for 29 - ocf_lct
# there is no data for 29 - int_debt
# there is no data for 29 - quick_ratio
# there is no data for 29 - rect_act
# there is no data for 29 - invt_act
# there is no data for 29 - dpr
# there is no data for 29 - pretret_noa
# there is no data for 29 - cash_ratio
# there is no data for 29 - curr_debt
# there is no data for 30 - profit_lct
# there is no data for 30 - curr_ratio
# there is no data for 30 - intcov_ratio
# there is no data for 30 - pretret_earnat
# there is no data for 30 - inv_turn
# there is no data for 30 - int_totdebt
# there is no data for 30 - 12_month_return
# there is no data for 30 - efftax
# there is no data for 30 - 3_month_return
# there is no data for 30 - intcov
# there is no data for 30 - ocf_lct
# there is no data for 30 - int_debt
# there is no data for 30 - quick_ratio
# there is no data for 30 - rect_act
# there is no data for 30 - invt_act
# there is no data for 30 - dpr
# there is no data for 30 - pretret_noa
# there is no data for 30 - cash_ratio
# there is no data for 30 - curr_debt
# there is no data for 31 - profit_lct
# there is no data for 31 - curr_ratio
# there is no data for 31 - intcov_ratio
# there is no data for 31 - pretret_earnat
# there is no data for 31 - inv_turn
# there is no data for 31 - int_totdebt
# there is no data for 31 - 12_month_return
# there is no data for 31 - efftax
# there is no data for 31 - 3_month_return
# there is no data for 31 - intcov
# there is no data for 31 - ocf_lct
# there is no data for 31 - int_debt
# there is no data for 31 - quick_ratio
# there is no data for 31 - rect_act
# there is no data for 31 - invt_act
# there is no data for 31 - dpr
# there is no data for 31 - pretret_noa
# there is no data for 31 - cash_ratio
# there is no data for 31 - curr_debt
# there is no data for 32 - profit_lct
# there is no data for 32 - curr_ratio
# there is no data for 32 - intcov_ratio
# there is no data for 32 - pretret_earnat
# there is no data for 32 - inv_turn
# there is no data for 32 - int_totdebt
# there is no data for 32 - 12_month_return
# there is no data for 32 - efftax
# there is no data for 32 - 3_month_return
# there is no data for 32 - intcov
# there is no data for 32 - ocf_lct
# there is no data for 32 - int_debt
# there is no data for 32 - quick_ratio
# there is no data for 32 - rect_act
# there is no data for 32 - invt_act
# there is no data for 32 - dpr
# there is no data for 32 - pretret_noa
# there is no data for 32 - cash_ratio
# there is no data for 32 - curr_debt
# there is no data for 33 - profit_lct
# there is no data for 33 - curr_ratio
# there is no data for 33 - intcov_ratio
# there is no data for 33 - pretret_earnat
# there is no data for 33 - inv_turn
# there is no data for 33 - int_totdebt
# there is no data for 33 - 12_month_return
# there is no data for 33 - efftax
# there is no data for 33 - 3_month_return
# there is no data for 33 - intcov
# there is no data for 33 - ocf_lct
# there is no data for 33 - int_debt
# there is no data for 33 - quick_ratio
# there is no data for 33 - rect_act
# there is no data for 33 - invt_act
# there is no data for 33 - dpr
# there is no data for 33 - pretret_noa
# there is no data for 33 - cash_ratio
# there is no data for 33 - curr_debt
# there is no data for 34 - profit_lct
# there is no data for 34 - curr_ratio
# there is no data for 34 - intcov_ratio
# there is no data for 34 - pretret_earnat
# there is no data for 34 - inv_turn
# there is no data for 34 - int_totdebt
# there is no data for 34 - 12_month_return
# there is no data for 34 - efftax
# there is no data for 34 - 3_month_return
# there is no data for 34 - intcov
# there is no data for 34 - ocf_lct
# there is no data for 34 - int_debt
# there is no data for 34 - quick_ratio
# there is no data for 34 - rect_act
# there is no data for 34 - invt_act
# there is no data for 34 - dpr
# there is no data for 34 - pretret_noa
# there is no data for 34 - cash_ratio
# there is no data for 34 - curr_debt
# there is no data for 35 - profit_lct
# there is no data for 35 - curr_ratio
# there is no data for 35 - intcov_ratio
# there is no data for 35 - pretret_earnat
# there is no data for 35 - inv_turn
# there is no data for 35 - int_totdebt
# there is no data for 35 - 12_month_return
# there is no data for 35 - efftax
# there is no data for 35 - 3_month_return
# there is no data for 35 - intcov
# there is no data for 35 - ocf_lct
# there is no data for 35 - int_debt
# there is no data for 35 - quick_ratio
# there is no data for 35 - rect_act
# there is no data for 35 - invt_act
# there is no data for 35 - dpr
# there is no data for 35 - pretret_noa
# there is no data for 35 - cash_ratio
# there is no data for 35 - curr_debt
# there is no data for 36 - profit_lct
# there is no data for 36 - curr_ratio
# there is no data for 36 - intcov_ratio
# there is no data for 36 - pretret_earnat
# there is no data for 36 - inv_turn
# there is no data for 36 - int_totdebt
# there is no data for 36 - 12_month_return
# there is no data for 36 - efftax
# there is no data for 36 - 3_month_return
# there is no data for 36 - intcov
# there is no data for 36 - ocf_lct
# there is no data for 36 - int_debt
# there is no data for 36 - quick_ratio
# there is no data for 36 - rect_act
# there is no data for 36 - invt_act
# there is no data for 36 - dpr
# there is no data for 36 - pretret_noa
# there is no data for 36 - cash_ratio
# there is no data for 36 - curr_debt
# there is no data for 37 - profit_lct
# there is no data for 37 - curr_ratio
# there is no data for 37 - intcov_ratio
# there is no data for 37 - pretret_earnat
# there is no data for 37 - inv_turn
# there is no data for 37 - int_totdebt
# there is no data for 37 - 12_month_return
# there is no data for 37 - efftax
# there is no data for 37 - 3_month_return
# there is no data for 37 - intcov
# there is no data for 37 - ocf_lct
# there is no data for 37 - int_debt
# there is no data for 37 - quick_ratio
# there is no data for 37 - rect_act
# there is no data for 37 - invt_act
# there is no data for 37 - dpr
# there is no data for 37 - pretret_noa
# there is no data for 37 - cash_ratio
# there is no data for 37 - curr_debt
# there is no data for 38 - profit_lct
# there is no data for 38 - curr_ratio
# there is no data for 38 - intcov_ratio
# there is no data for 38 - pretret_earnat
# there is no data for 38 - inv_turn
# there is no data for 38 - int_totdebt
# there is no data for 38 - 12_month_return
# there is no data for 38 - efftax
# there is no data for 38 - 3_month_return
# there is no data for 38 - intcov
# there is no data for 38 - ocf_lct
# there is no data for 38 - int_debt
# there is no data for 38 - quick_ratio
# there is no data for 38 - rect_act
# there is no data for 38 - invt_act
# there is no data for 38 - dpr
# there is no data for 38 - pretret_noa
# there is no data for 38 - cash_ratio
# there is no data for 38 - curr_debt
# there is no data for 39 - profit_lct
# there is no data for 39 - curr_ratio
# there is no data for 39 - intcov_ratio
# there is no data for 39 - pretret_earnat
# there is no data for 39 - inv_turn
# there is no data for 39 - int_totdebt
# there is no data for 39 - 12_month_return
# there is no data for 39 - efftax
# there is no data for 39 - 3_month_return
# there is no data for 39 - intcov
# there is no data for 39 - ocf_lct
# there is no data for 39 - int_debt
# there is no data for 39 - quick_ratio
# there is no data for 39 - rect_act
# there is no data for 39 - invt_act
# there is no data for 39 - dpr
# there is no data for 39 - pretret_noa
# there is no data for 39 - cash_ratio
# there is no data for 39 - curr_debt
# there is no data for 40 - profit_lct
# there is no data for 40 - curr_ratio
# there is no data for 40 - intcov_ratio
# there is no data for 40 - pretret_earnat
# there is no data for 40 - inv_turn
# there is no data for 40 - int_totdebt
# there is no data for 40 - 12_month_return
# there is no data for 40 - efftax
# there is no data for 40 - 3_month_return
# there is no data for 40 - intcov
# there is no data for 40 - ocf_lct
# there is no data for 40 - int_debt
# there is no data for 40 - quick_ratio
# there is no data for 40 - rect_act
# there is no data for 40 - invt_act
# there is no data for 40 - dpr
# there is no data for 40 - pretret_noa
# there is no data for 40 - cash_ratio
# there is no data for 40 - curr_debt
# there is no data for 41 - profit_lct
# there is no data for 41 - curr_ratio
# there is no data for 41 - intcov_ratio
# there is no data for 41 - pretret_earnat
# there is no data for 41 - inv_turn
# there is no data for 41 - int_totdebt
# there is no data for 41 - 12_month_return
# there is no data for 41 - efftax
# there is no data for 41 - 3_month_return
# there is no data for 41 - intcov
# there is no data for 41 - ocf_lct
# there is no data for 41 - int_debt
# there is no data for 41 - quick_ratio
# there is no data for 41 - rect_act
# there is no data for 41 - invt_act
# there is no data for 41 - dpr
# there is no data for 41 - pretret_noa
# there is no data for 41 - cash_ratio
# there is no data for 41 - curr_debt
# there is no data for 42 - profit_lct
# there is no data for 42 - curr_ratio
# there is no data for 42 - intcov_ratio
# there is no data for 42 - pretret_earnat
# there is no data for 42 - inv_turn
# there is no data for 42 - int_totdebt
# there is no data for 42 - 12_month_return
# there is no data for 42 - efftax
# there is no data for 42 - 3_month_return
# there is no data for 42 - intcov
# there is no data for 42 - ocf_lct
# there is no data for 42 - int_debt
# there is no data for 42 - quick_ratio
# there is no data for 42 - rect_act
# there is no data for 42 - invt_act
# there is no data for 42 - dpr
# there is no data for 42 - pretret_noa
# there is no data for 42 - cash_ratio
# there is no data for 42 - curr_debt
# there is no data for 43 - profit_lct
# there is no data for 43 - curr_ratio
# there is no data for 43 - intcov_ratio
# there is no data for 43 - pretret_earnat
# there is no data for 43 - inv_turn
# there is no data for 43 - int_totdebt
# there is no data for 43 - 12_month_return
# there is no data for 43 - efftax
# there is no data for 43 - 3_month_return
# there is no data for 43 - intcov
# there is no data for 43 - ocf_lct
# there is no data for 43 - int_debt
# there is no data for 43 - quick_ratio
# there is no data for 43 - rect_act
# there is no data for 43 - invt_act
# there is no data for 43 - dpr
# there is no data for 43 - pretret_noa
# there is no data for 43 - cash_ratio
# there is no data for 43 - curr_debt
# there is no data for 44 - profit_lct
# there is no data for 44 - curr_ratio
# there is no data for 44 - intcov_ratio
# there is no data for 44 - pretret_earnat
# there is no data for 44 - inv_turn
# there is no data for 44 - int_totdebt
# there is no data for 44 - 12_month_return
# there is no data for 44 - efftax
# there is no data for 44 - 3_month_return
# there is no data for 44 - intcov
# there is no data for 44 - ocf_lct
# there is no data for 44 - int_debt
# there is no data for 44 - quick_ratio
# there is no data for 44 - rect_act
# there is no data for 44 - invt_act
# there is no data for 44 - dpr
# there is no data for 44 - pretret_noa
# there is no data for 44 - cash_ratio
# there is no data for 44 - curr_debt
# there is no data for 45 - profit_lct
# there is no data for 45 - curr_ratio
# there is no data for 45 - intcov_ratio
# there is no data for 45 - pretret_earnat
# there is no data for 45 - inv_turn
# there is no data for 45 - int_totdebt
# there is no data for 45 - 12_month_return
# there is no data for 45 - efftax
# there is no data for 45 - 3_month_return
# there is no data for 45 - intcov
# there is no data for 45 - ocf_lct
# there is no data for 45 - int_debt
# there is no data for 45 - quick_ratio
# there is no data for 45 - rect_act
# there is no data for 45 - invt_act
# there is no data for 45 - dpr
# there is no data for 45 - pretret_noa
# there is no data for 45 - cash_ratio
# there is no data for 45 - curr_debt
# there is no data for 46 - profit_lct
# there is no data for 46 - curr_ratio
# there is no data for 46 - intcov_ratio
# there is no data for 46 - pretret_earnat
# there is no data for 46 - inv_turn
# there is no data for 46 - int_totdebt
# there is no data for 46 - 12_month_return
# there is no data for 46 - efftax
# there is no data for 46 - 3_month_return
# there is no data for 46 - intcov
# there is no data for 46 - ocf_lct
# there is no data for 46 - int_debt
# there is no data for 46 - quick_ratio
# there is no data for 46 - rect_act
# there is no data for 46 - invt_act
# there is no data for 46 - dpr
# there is no data for 46 - pretret_noa
# there is no data for 46 - cash_ratio
# there is no data for 46 - curr_debt
# there is no data for 47 - profit_lct
# there is no data for 47 - curr_ratio
# there is no data for 47 - intcov_ratio
# there is no data for 47 - pretret_earnat
# there is no data for 47 - inv_turn
# there is no data for 47 - int_totdebt
# there is no data for 47 - 12_month_return
# there is no data for 47 - efftax
# there is no data for 47 - 3_month_return
# there is no data for 47 - intcov
# there is no data for 47 - ocf_lct
# there is no data for 47 - int_debt
# there is no data for 47 - quick_ratio
# there is no data for 47 - rect_act
# there is no data for 47 - invt_act
# there is no data for 47 - dpr
# there is no data for 47 - pretret_noa
# there is no data for 47 - cash_ratio
# there is no data for 47 - curr_debt
# there is no data for 48 - profit_lct
# there is no data for 48 - curr_ratio
# there is no data for 48 - intcov_ratio
# there is no data for 48 - pretret_earnat
# there is no data for 48 - inv_turn
# there is no data for 48 - int_totdebt
# there is no data for 48 - 12_month_return
# there is no data for 48 - efftax
# there is no data for 48 - 3_month_return
# there is no data for 48 - intcov
# there is no data for 48 - ocf_lct
# there is no data for 48 - int_debt
# there is no data for 48 - quick_ratio
# there is no data for 48 - rect_act
# there is no data for 48 - invt_act
# there is no data for 48 - dpr
# there is no data for 48 - pretret_noa
# there is no data for 48 - cash_ratio
# there is no data for 48 - curr_debt
# there is no data for 49 - profit_lct
# there is no data for 49 - curr_ratio
# there is no data for 49 - intcov_ratio
# there is no data for 49 - pretret_earnat
# there is no data for 49 - inv_turn
# there is no data for 49 - int_totdebt
# there is no data for 49 - 12_month_return
# there is no data for 49 - efftax
# there is no data for 49 - 3_month_return
# there is no data for 49 - intcov
# there is no data for 49 - ocf_lct
# there is no data for 49 - int_debt
# there is no data for 49 - quick_ratio
# there is no data for 49 - rect_act
# there is no data for 49 - invt_act
# there is no data for 49 - dpr
# there is no data for 49 - pretret_noa
# there is no data for 49 - cash_ratio
# there is no data for 49 - curr_debt
# there is no data for 50 - profit_lct
# there is no data for 50 - curr_ratio
# there is no data for 50 - intcov_ratio
# there is no data for 50 - pretret_earnat
# there is no data for 50 - inv_turn
# there is no data for 50 - int_totdebt
# there is no data for 50 - 12_month_return
# there is no data for 50 - efftax
# there is no data for 50 - 3_month_return
# there is no data for 50 - intcov
# there is no data for 50 - ocf_lct
# there is no data for 50 - int_debt
# there is no data for 50 - quick_ratio
# there is no data for 50 - rect_act
# there is no data for 50 - invt_act
# there is no data for 50 - dpr
# there is no data for 50 - pretret_noa
# there is no data for 50 - cash_ratio
# there is no data for 50 - curr_debt
# there is no data for 51 - profit_lct
# there is no data for 51 - curr_ratio
# there is no data for 51 - intcov_ratio
# there is no data for 51 - pretret_earnat
# there is no data for 51 - inv_turn
# there is no data for 51 - int_totdebt
# there is no data for 51 - 12_month_return
# there is no data for 51 - efftax
# there is no data for 51 - 3_month_return
# there is no data for 51 - intcov
# there is no data for 51 - ocf_lct
# there is no data for 51 - int_debt
# there is no data for 51 - quick_ratio
# there is no data for 51 - rect_act
# there is no data for 51 - invt_act
# there is no data for 51 - dpr
# there is no data for 51 - pretret_noa
# there is no data for 51 - cash_ratio
# there is no data for 51 - curr_debt
# there is no data for 52 - profit_lct
# there is no data for 52 - curr_ratio
# there is no data for 52 - intcov_ratio
# there is no data for 52 - pretret_earnat
# there is no data for 52 - inv_turn
# there is no data for 52 - int_totdebt
# there is no data for 52 - 12_month_return
# there is no data for 52 - efftax
# there is no data for 52 - 3_month_return
# there is no data for 52 - intcov
# there is no data for 52 - ocf_lct
# there is no data for 52 - int_debt
# there is no data for 52 - quick_ratio
# there is no data for 52 - rect_act
# there is no data for 52 - invt_act
# there is no data for 52 - dpr
# there is no data for 52 - pretret_noa
# there is no data for 52 - cash_ratio
# there is no data for 52 - curr_debt
# there is no data for 53 - profit_lct
# there is no data for 53 - curr_ratio
# there is no data for 53 - intcov_ratio
# there is no data for 53 - pretret_earnat
# there is no data for 53 - inv_turn
# there is no data for 53 - int_totdebt
# there is no data for 53 - 12_month_return
# there is no data for 53 - efftax
# there is no data for 53 - 3_month_return
# there is no data for 53 - intcov
# there is no data for 53 - ocf_lct
# there is no data for 53 - int_debt
# there is no data for 53 - quick_ratio
# there is no data for 53 - rect_act
# there is no data for 53 - invt_act
# there is no data for 53 - dpr
# there is no data for 53 - pretret_noa
# there is no data for 53 - cash_ratio
# there is no data for 53 - curr_debt
# there is no data for 54 - profit_lct
# there is no data for 54 - curr_ratio
# there is no data for 54 - intcov_ratio
# there is no data for 54 - pretret_earnat
# there is no data for 54 - inv_turn
# there is no data for 54 - int_totdebt
# there is no data for 54 - 12_month_return
# there is no data for 54 - efftax
# there is no data for 54 - 3_month_return
# there is no data for 54 - intcov
# there is no data for 54 - ocf_lct
# there is no data for 54 - int_debt
# there is no data for 54 - quick_ratio
# there is no data for 54 - rect_act
# there is no data for 54 - invt_act
# there is no data for 54 - dpr
# there is no data for 54 - pretret_noa
# there is no data for 54 - cash_ratio
# there is no data for 54 - curr_debt
# there is no data for 55 - profit_lct
# there is no data for 55 - curr_ratio
# there is no data for 55 - intcov_ratio
# there is no data for 55 - pretret_earnat
# there is no data for 55 - inv_turn
# there is no data for 55 - int_totdebt
# there is no data for 55 - 12_month_return
# there is no data for 55 - efftax
# there is no data for 55 - 3_month_return
# there is no data for 55 - intcov
# there is no data for 55 - ocf_lct
# there is no data for 55 - int_debt
# there is no data for 55 - quick_ratio
# there is no data for 55 - rect_act
# there is no data for 55 - invt_act
# there is no data for 55 - dpr
# there is no data for 55 - pretret_noa
# there is no data for 55 - cash_ratio
# there is no data for 55 - curr_debt
# there is no data for 56 - profit_lct
# there is no data for 56 - curr_ratio
# there is no data for 56 - intcov_ratio
# there is no data for 56 - pretret_earnat
# there is no data for 56 - inv_turn
# there is no data for 56 - int_totdebt
# there is no data for 56 - 12_month_return
# there is no data for 56 - efftax
# there is no data for 56 - 3_month_return
# there is no data for 56 - intcov
# there is no data for 56 - ocf_lct
# there is no data for 56 - int_debt
# there is no data for 56 - quick_ratio
# there is no data for 56 - rect_act
# there is no data for 56 - invt_act
# there is no data for 56 - dpr
# there is no data for 56 - pretret_noa
# there is no data for 56 - cash_ratio
# there is no data for 56 - curr_debt
# there is no data for 57 - profit_lct
# there is no data for 57 - curr_ratio
# there is no data for 57 - intcov_ratio
# there is no data for 57 - pretret_earnat
# there is no data for 57 - inv_turn
# there is no data for 57 - int_totdebt
# there is no data for 57 - 12_month_return
# there is no data for 57 - efftax
# there is no data for 57 - 3_month_return
# there is no data for 57 - intcov
# there is no data for 57 - ocf_lct
# there is no data for 57 - int_debt
# there is no data for 57 - quick_ratio
# there is no data for 57 - rect_act
# there is no data for 57 - invt_act
# there is no data for 57 - dpr
# there is no data for 57 - pretret_noa
# there is no data for 57 - cash_ratio
# there is no data for 57 - curr_debt
# there is no data for 58 - profit_lct
# there is no data for 58 - curr_ratio
# there is no data for 58 - intcov_ratio
# there is no data for 58 - pretret_earnat
# there is no data for 58 - inv_turn
# there is no data for 58 - int_totdebt
# there is no data for 58 - 12_month_return
# there is no data for 58 - efftax
# there is no data for 58 - 3_month_return
# there is no data for 58 - intcov
# there is no data for 58 - ocf_lct
# there is no data for 58 - int_debt
# there is no data for 58 - quick_ratio
# there is no data for 58 - rect_act
# there is no data for 58 - invt_act
# there is no data for 58 - dpr
# there is no data for 58 - pretret_noa
# there is no data for 58 - cash_ratio
# there is no data for 58 - curr_debt
# there is no data for 59 - profit_lct
# there is no data for 59 - curr_ratio
# there is no data for 59 - intcov_ratio
# there is no data for 59 - pretret_earnat
# there is no data for 59 - inv_turn
# there is no data for 59 - int_totdebt
# there is no data for 59 - 12_month_return
# there is no data for 59 - efftax
# there is no data for 59 - 3_month_return
# there is no data for 59 - intcov
# there is no data for 59 - ocf_lct
# there is no data for 59 - int_debt
# there is no data for 59 - quick_ratio
# there is no data for 59 - rect_act
# there is no data for 59 - invt_act
# there is no data for 59 - dpr
# there is no data for 59 - pretret_noa
# there is no data for 59 - cash_ratio
# there is no data for 59 - curr_debt
# there is no data for 60 - profit_lct
# there is no data for 60 - curr_ratio
# there is no data for 60 - intcov_ratio
# there is no data for 60 - pretret_earnat
# there is no data for 60 - inv_turn
# there is no data for 60 - int_totdebt
# there is no data for 60 - 12_month_return
# there is no data for 60 - efftax
# there is no data for 60 - 3_month_return
# there is no data for 60 - intcov
# there is no data for 60 - ocf_lct
# there is no data for 60 - int_debt
# there is no data for 60 - quick_ratio
# there is no data for 60 - rect_act
# there is no data for 60 - invt_act
# there is no data for 60 - dpr
# there is no data for 60 - pretret_noa
# there is no data for 60 - cash_ratio
# there is no data for 60 - curr_debt
# there is no data for 61 - profit_lct
# there is no data for 61 - curr_ratio
# there is no data for 61 - intcov_ratio
# there is no data for 61 - pretret_earnat
# there is no data for 61 - inv_turn
# there is no data for 61 - int_totdebt
# there is no data for 61 - 12_month_return
# there is no data for 61 - efftax
# there is no data for 61 - 3_month_return
# there is no data for 61 - intcov
# there is no data for 61 - ocf_lct
# there is no data for 61 - int_debt
# there is no data for 61 - quick_ratio
# there is no data for 61 - rect_act
# there is no data for 61 - invt_act
# there is no data for 61 - dpr
# there is no data for 61 - pretret_noa
# there is no data for 61 - cash_ratio
# there is no data for 61 - curr_debt
# there is no data for 62 - profit_lct
# there is no data for 62 - curr_ratio
# there is no data for 62 - intcov_ratio
# there is no data for 62 - pretret_earnat
# there is no data for 62 - inv_turn
# there is no data for 62 - int_totdebt
# there is no data for 62 - 12_month_return
# there is no data for 62 - efftax
# there is no data for 62 - 3_month_return
# there is no data for 62 - intcov
# there is no data for 62 - ocf_lct
# there is no data for 62 - int_debt
# there is no data for 62 - quick_ratio
# there is no data for 62 - rect_act
# there is no data for 62 - invt_act
# there is no data for 62 - dpr
# there is no data for 62 - pretret_noa
# there is no data for 62 - cash_ratio
# there is no data for 62 - curr_debt
# there is no data for 63 - profit_lct
# there is no data for 63 - curr_ratio
# there is no data for 63 - intcov_ratio
# there is no data for 63 - pretret_earnat
# there is no data for 63 - inv_turn
# there is no data for 63 - int_totdebt
# there is no data for 63 - 12_month_return
# there is no data for 63 - efftax
# there is no data for 63 - 3_month_return
# there is no data for 63 - intcov
# there is no data for 63 - ocf_lct
# there is no data for 63 - int_debt
# there is no data for 63 - quick_ratio
# there is no data for 63 - rect_act
# there is no data for 63 - invt_act
# there is no data for 63 - dpr
# there is no data for 63 - pretret_noa
# there is no data for 63 - cash_ratio
# there is no data for 63 - curr_debt
# there is no data for 64 - profit_lct
# there is no data for 64 - curr_ratio
# there is no data for 64 - intcov_ratio
# there is no data for 64 - pretret_earnat
# there is no data for 64 - inv_turn
# there is no data for 64 - int_totdebt
# there is no data for 64 - 12_month_return
# there is no data for 64 - efftax
# there is no data for 64 - 3_month_return
# there is no data for 64 - intcov
# there is no data for 64 - ocf_lct
# there is no data for 64 - int_debt
# there is no data for 64 - quick_ratio
# there is no data for 64 - rect_act
# there is no data for 64 - invt_act
# there is no data for 64 - dpr
# there is no data for 64 - pretret_noa
# there is no data for 64 - cash_ratio
# there is no data for 64 - curr_debt
# there is no data for 65 - profit_lct
# there is no data for 65 - curr_ratio
# there is no data for 65 - intcov_ratio
# there is no data for 65 - pretret_earnat
# there is no data for 65 - inv_turn
# there is no data for 65 - int_totdebt
# there is no data for 65 - 12_month_return
# there is no data for 65 - efftax
# there is no data for 65 - 3_month_return
# there is no data for 65 - intcov
# there is no data for 65 - ocf_lct
# there is no data for 65 - int_debt
# there is no data for 65 - quick_ratio
# there is no data for 65 - rect_act
# there is no data for 65 - invt_act
# there is no data for 65 - dpr
# there is no data for 65 - pretret_noa
# there is no data for 65 - cash_ratio
# there is no data for 65 - curr_debt
# there is no data for 66 - profit_lct
# there is no data for 66 - curr_ratio
# there is no data for 66 - intcov_ratio
# there is no data for 66 - pretret_earnat
# there is no data for 66 - inv_turn
# there is no data for 66 - int_totdebt
# there is no data for 66 - 12_month_return
# there is no data for 66 - efftax
# there is no data for 66 - 3_month_return
# there is no data for 66 - intcov
# there is no data for 66 - ocf_lct
# there is no data for 66 - int_debt
# there is no data for 66 - quick_ratio
# there is no data for 66 - rect_act
# there is no data for 66 - invt_act
# there is no data for 66 - dpr
# there is no data for 66 - pretret_noa
# there is no data for 66 - cash_ratio
# there is no data for 66 - curr_debt
# there is no data for 67 - profit_lct
# there is no data for 67 - curr_ratio
# there is no data for 67 - intcov_ratio
# there is no data for 67 - pretret_earnat
# there is no data for 67 - inv_turn
# there is no data for 67 - int_totdebt
# there is no data for 67 - 12_month_return
# there is no data for 67 - efftax
# there is no data for 67 - 3_month_return
# there is no data for 67 - intcov
# there is no data for 67 - ocf_lct
# there is no data for 67 - int_debt
# there is no data for 67 - quick_ratio
# there is no data for 67 - rect_act
# there is no data for 67 - invt_act
# there is no data for 67 - dpr
# there is no data for 67 - pretret_noa
# there is no data for 67 - cash_ratio
# there is no data for 67 - curr_debt
# there is no data for 68 - profit_lct
# there is no data for 68 - curr_ratio
# there is no data for 68 - intcov_ratio
# there is no data for 68 - pretret_earnat
# there is no data for 68 - inv_turn
# there is no data for 68 - int_totdebt
# there is no data for 68 - 12_month_return
# there is no data for 68 - efftax
# there is no data for 68 - 3_month_return
# there is no data for 68 - intcov
# there is no data for 68 - ocf_lct
# there is no data for 68 - int_debt
# there is no data for 68 - quick_ratio
# there is no data for 68 - rect_act
# there is no data for 68 - invt_act
# there is no data for 68 - dpr
# there is no data for 68 - pretret_noa
# ...
# there is no data for 917 - invt_act
# there is no data for 917 - dpr
# there is no data for 917 - pretret_noa
# there is no data for 917 - cash_ratio
# there is no data for 917 - curr_debt
# there is no data for 918 - profit_lct
# there is no data for 918 - curr_ratio
# there is no data for 918 - intcov_ratio
# there is no data for 918 - pretret_earnat
# there is no data for 918 - inv_turn
# there is no data for 918 - int_totdebt
# there is no data for 918 - 12_month_return
# there is no data for 918 - efftax
# there is no data for 918 - 3_month_return
# there is no data for 918 - intcov
# there is no data for 918 - ocf_lct
# there is no data for 918 - int_debt
# there is no data for 918 - quick_ratio
# there is no data for 918 - rect_act
# there is no data for 918 - invt_act
# there is no data for 918 - dpr
# there is no data for 918 - pretret_noa
# there is no data for 918 - cash_ratio
# there is no data for 918 - curr_debt
# there is no data for 919 - profit_lct
# there is no data for 919 - curr_ratio
# there is no data for 919 - intcov_ratio
# there is no data for 919 - pretret_earnat
# there is no data for 919 - inv_turn
# there is no data for 919 - int_totdebt
# there is no data for 919 - 12_month_return
# there is no data for 919 - efftax
# there is no data for 919 - 3_month_return
# there is no data for 919 - intcov
# there is no data for 919 - ocf_lct
# there is no data for 919 - int_debt
# there is no data for 919 - quick_ratio
# there is no data for 919 - rect_act
# there is no data for 919 - invt_act
# there is no data for 919 - dpr
# there is no data for 919 - pretret_noa
# there is no data for 919 - cash_ratio
# there is no data for 919 - curr_debt
# there is no data for 920 - profit_lct
# there is no data for 920 - curr_ratio
# there is no data for 920 - intcov_ratio
# there is no data for 920 - pretret_earnat
# there is no data for 920 - inv_turn
# there is no data for 920 - int_totdebt
# there is no data for 920 - 12_month_return
# there is no data for 920 - efftax
# there is no data for 920 - 3_month_return
# there is no data for 920 - intcov
# there is no data for 920 - ocf_lct
# there is no data for 920 - int_debt
# there is no data for 920 - quick_ratio
# there is no data for 920 - rect_act
# there is no data for 920 - invt_act
# there is no data for 920 - dpr
# there is no data for 920 - pretret_noa
# there is no data for 920 - cash_ratio
# there is no data for 920 - curr_debt
# there is no data for 921 - profit_lct
# there is no data for 921 - curr_ratio
# there is no data for 921 - intcov_ratio
# there is no data for 921 - pretret_earnat
# there is no data for 921 - inv_turn
# there is no data for 921 - int_totdebt
# there is no data for 921 - 12_month_return
# there is no data for 921 - efftax
# there is no data for 921 - 3_month_return
# there is no data for 921 - intcov
# there is no data for 921 - ocf_lct
# there is no data for 921 - int_debt
# there is no data for 921 - quick_ratio
# there is no data for 921 - rect_act
# there is no data for 921 - invt_act
# there is no data for 921 - dpr
# there is no data for 921 - pretret_noa
# there is no data for 921 - cash_ratio
# there is no data for 921 - curr_debt
# there is no data for 922 - profit_lct
# there is no data for 922 - curr_ratio
# there is no data for 922 - intcov_ratio
# there is no data for 922 - pretret_earnat
# there is no data for 922 - inv_turn
# there is no data for 922 - int_totdebt
# there is no data for 922 - 12_month_return
# there is no data for 922 - efftax
# there is no data for 922 - 3_month_return
# there is no data for 922 - intcov
# there is no data for 922 - ocf_lct
# there is no data for 922 - int_debt
# there is no data for 922 - quick_ratio
# there is no data for 922 - rect_act
# there is no data for 922 - invt_act
# there is no data for 922 - dpr
# there is no data for 922 - pretret_noa
# there is no data for 922 - cash_ratio
# there is no data for 922 - curr_debt
# there is no data for 923 - profit_lct
# there is no data for 923 - curr_ratio
# there is no data for 923 - intcov_ratio
# there is no data for 923 - pretret_earnat
# there is no data for 923 - inv_turn
# there is no data for 923 - int_totdebt
# there is no data for 923 - 12_month_return
# there is no data for 923 - efftax
# there is no data for 923 - 3_month_return
# there is no data for 923 - intcov
# there is no data for 923 - ocf_lct
# there is no data for 923 - int_debt
# there is no data for 923 - quick_ratio
# there is no data for 923 - rect_act
# there is no data for 923 - invt_act
# there is no data for 923 - dpr
# there is no data for 923 - pretret_noa
# there is no data for 923 - cash_ratio
# there is no data for 923 - curr_debt
# there is no data for 924 - profit_lct
# there is no data for 924 - curr_ratio
# there is no data for 924 - intcov_ratio
# there is no data for 924 - pretret_earnat
# there is no data for 924 - inv_turn
# there is no data for 924 - int_totdebt
# there is no data for 924 - 12_month_return
# there is no data for 924 - efftax
# there is no data for 924 - 3_month_return
# there is no data for 924 - intcov
# there is no data for 924 - ocf_lct
# there is no data for 924 - int_debt
# there is no data for 924 - quick_ratio
# there is no data for 924 - rect_act
# there is no data for 924 - invt_act
# there is no data for 924 - dpr
# there is no data for 924 - pretret_noa
# there is no data for 924 - cash_ratio
# there is no data for 924 - curr_debt
# there is no data for 925 - profit_lct
# there is no data for 925 - curr_ratio
# there is no data for 925 - intcov_ratio
# there is no data for 925 - pretret_earnat
# there is no data for 925 - inv_turn
# there is no data for 925 - int_totdebt
# there is no data for 925 - 12_month_return
# there is no data for 925 - efftax
# there is no data for 925 - 3_month_return
# there is no data for 925 - intcov
# there is no data for 925 - ocf_lct
# there is no data for 925 - int_debt
# there is no data for 925 - quick_ratio
# there is no data for 925 - rect_act
# there is no data for 925 - invt_act
# there is no data for 925 - dpr
# there is no data for 925 - pretret_noa
# there is no data for 925 - cash_ratio
# there is no data for 925 - curr_debt
# there is no data for 926 - profit_lct
# there is no data for 926 - curr_ratio
# there is no data for 926 - intcov_ratio
# there is no data for 926 - pretret_earnat
# there is no data for 926 - inv_turn
# there is no data for 926 - int_totdebt
# there is no data for 926 - 12_month_return
# there is no data for 926 - efftax
# there is no data for 926 - 3_month_return
# there is no data for 926 - intcov
# there is no data for 926 - ocf_lct
# there is no data for 926 - int_debt
# there is no data for 926 - quick_ratio
# there is no data for 926 - rect_act
# there is no data for 926 - invt_act
# there is no data for 926 - dpr
# there is no data for 926 - pretret_noa
# there is no data for 926 - cash_ratio
# there is no data for 926 - curr_debt
# there is no data for 927 - profit_lct
# there is no data for 927 - curr_ratio
# there is no data for 927 - intcov_ratio
# there is no data for 927 - pretret_earnat
# there is no data for 927 - inv_turn
# there is no data for 927 - int_totdebt
# there is no data for 927 - 12_month_return
# there is no data for 927 - efftax
# there is no data for 927 - 3_month_return
# there is no data for 927 - intcov
# there is no data for 927 - ocf_lct
# there is no data for 927 - int_debt
# there is no data for 927 - quick_ratio
# there is no data for 927 - rect_act
# there is no data for 927 - invt_act
# there is no data for 927 - dpr
# there is no data for 927 - pretret_noa
# there is no data for 927 - cash_ratio
# there is no data for 927 - curr_debt
# there is no data for 928 - profit_lct
# there is no data for 928 - curr_ratio
# there is no data for 928 - intcov_ratio
# there is no data for 928 - pretret_earnat
# there is no data for 928 - inv_turn
# there is no data for 928 - int_totdebt
# there is no data for 928 - 12_month_return
# there is no data for 928 - efftax
# there is no data for 928 - 3_month_return
# there is no data for 928 - intcov
# there is no data for 928 - ocf_lct
# there is no data for 928 - int_debt
# there is no data for 928 - quick_ratio
# there is no data for 928 - rect_act
# there is no data for 928 - invt_act
# there is no data for 928 - dpr
# there is no data for 928 - pretret_noa
# there is no data for 928 - cash_ratio
# there is no data for 928 - curr_debt
# there is no data for 929 - profit_lct
# there is no data for 929 - curr_ratio
# there is no data for 929 - intcov_ratio
# there is no data for 929 - pretret_earnat
# there is no data for 929 - inv_turn
# there is no data for 929 - int_totdebt
# there is no data for 929 - 12_month_return
# there is no data for 929 - efftax
# there is no data for 929 - 3_month_return
# there is no data for 929 - intcov
# there is no data for 929 - ocf_lct
# there is no data for 929 - int_debt
# there is no data for 929 - quick_ratio
# there is no data for 929 - rect_act
# there is no data for 929 - invt_act
# there is no data for 929 - dpr
# there is no data for 929 - pretret_noa
# there is no data for 929 - cash_ratio
# there is no data for 929 - curr_debt
# there is no data for 930 - profit_lct
# there is no data for 930 - curr_ratio
# there is no data for 930 - intcov_ratio
# there is no data for 930 - pretret_earnat
# there is no data for 930 - inv_turn
# there is no data for 930 - int_totdebt
# there is no data for 930 - 12_month_return
# there is no data for 930 - efftax
# there is no data for 930 - 3_month_return
# there is no data for 930 - intcov
# there is no data for 930 - ocf_lct
# there is no data for 930 - int_debt
# there is no data for 930 - quick_ratio
# there is no data for 930 - rect_act
# there is no data for 930 - invt_act
# there is no data for 930 - dpr
# there is no data for 930 - pretret_noa
# there is no data for 930 - cash_ratio
# there is no data for 930 - curr_debt
# there is no data for 931 - profit_lct
# there is no data for 931 - curr_ratio
# there is no data for 931 - intcov_ratio
# there is no data for 931 - pretret_earnat
# there is no data for 931 - inv_turn
# there is no data for 931 - int_totdebt
# there is no data for 931 - 12_month_return
# there is no data for 931 - efftax
# there is no data for 931 - 3_month_return
# there is no data for 931 - intcov
# there is no data for 931 - ocf_lct
# there is no data for 931 - int_debt
# there is no data for 931 - quick_ratio
# there is no data for 931 - rect_act
# there is no data for 931 - invt_act
# there is no data for 931 - dpr
# there is no data for 931 - pretret_noa
# there is no data for 931 - cash_ratio
# there is no data for 931 - curr_debt
# there is no data for 932 - profit_lct
# there is no data for 932 - curr_ratio
# there is no data for 932 - intcov_ratio
# there is no data for 932 - pretret_earnat
# there is no data for 932 - inv_turn
# there is no data for 932 - int_totdebt
# there is no data for 932 - 12_month_return
# there is no data for 932 - efftax
# there is no data for 932 - 3_month_return
# there is no data for 932 - intcov
# there is no data for 932 - ocf_lct
# there is no data for 932 - int_debt
# there is no data for 932 - quick_ratio
# there is no data for 932 - rect_act
# there is no data for 932 - invt_act
# there is no data for 932 - dpr
# there is no data for 932 - pretret_noa
# there is no data for 932 - cash_ratio
# there is no data for 932 - curr_debt
# there is no data for 933 - profit_lct
# there is no data for 933 - curr_ratio
# there is no data for 933 - intcov_ratio
# there is no data for 933 - pretret_earnat
# there is no data for 933 - inv_turn
# there is no data for 933 - int_totdebt
# there is no data for 933 - 12_month_return
# there is no data for 933 - efftax
# there is no data for 933 - 3_month_return
# there is no data for 933 - intcov
# there is no data for 933 - ocf_lct
# there is no data for 933 - int_debt
# there is no data for 933 - quick_ratio
# there is no data for 933 - rect_act
# there is no data for 933 - invt_act
# there is no data for 933 - dpr
# there is no data for 933 - pretret_noa
# there is no data for 933 - cash_ratio
# there is no data for 933 - curr_debt
# there is no data for 934 - profit_lct
# there is no data for 934 - curr_ratio
# there is no data for 934 - intcov_ratio
# there is no data for 934 - pretret_earnat
# there is no data for 934 - inv_turn
# there is no data for 934 - int_totdebt
# there is no data for 934 - 12_month_return
# there is no data for 934 - efftax
# there is no data for 934 - 3_month_return
# there is no data for 934 - intcov
# there is no data for 934 - ocf_lct
# there is no data for 934 - int_debt
# there is no data for 934 - quick_ratio
# there is no data for 934 - rect_act
# there is no data for 934 - invt_act
# there is no data for 934 - dpr
# there is no data for 934 - pretret_noa
# there is no data for 934 - cash_ratio
# there is no data for 934 - curr_debt
# there is no data for 935 - profit_lct
# there is no data for 935 - curr_ratio
# there is no data for 935 - intcov_ratio
# there is no data for 935 - pretret_earnat
# there is no data for 935 - inv_turn
# there is no data for 935 - int_totdebt
# there is no data for 935 - 12_month_return
# there is no data for 935 - efftax
# there is no data for 935 - 3_month_return
# there is no data for 935 - intcov
# there is no data for 935 - ocf_lct
# there is no data for 935 - int_debt
# there is no data for 935 - quick_ratio
# there is no data for 935 - rect_act
# there is no data for 935 - invt_act
# there is no data for 935 - dpr
# there is no data for 935 - pretret_noa
# there is no data for 935 - cash_ratio
# there is no data for 935 - curr_debt
# there is no data for 936 - profit_lct
# there is no data for 936 - curr_ratio
# there is no data for 936 - intcov_ratio
# there is no data for 936 - pretret_earnat
# there is no data for 936 - inv_turn
# there is no data for 936 - int_totdebt
# there is no data for 936 - 12_month_return
# there is no data for 936 - efftax
# there is no data for 936 - 3_month_return
# there is no data for 936 - intcov
# there is no data for 936 - ocf_lct
# there is no data for 936 - int_debt
# there is no data for 936 - quick_ratio
# there is no data for 936 - rect_act
# there is no data for 936 - invt_act
# there is no data for 936 - dpr
# there is no data for 936 - pretret_noa
# there is no data for 936 - cash_ratio
# there is no data for 936 - curr_debt
# there is no data for 937 - profit_lct
# there is no data for 937 - curr_ratio
# there is no data for 937 - intcov_ratio
# there is no data for 937 - pretret_earnat
# there is no data for 937 - inv_turn
# there is no data for 937 - int_totdebt
# there is no data for 937 - 12_month_return
# there is no data for 937 - efftax
# there is no data for 937 - 3_month_return
# there is no data for 937 - intcov
# there is no data for 937 - ocf_lct
# there is no data for 937 - int_debt
# there is no data for 937 - quick_ratio
# there is no data for 937 - rect_act
# there is no data for 937 - invt_act
# there is no data for 937 - dpr
# there is no data for 937 - pretret_noa
# there is no data for 937 - cash_ratio
# there is no data for 937 - curr_debt
# there is no data for 938 - profit_lct
# there is no data for 938 - curr_ratio
# there is no data for 938 - intcov_ratio
# there is no data for 938 - pretret_earnat
# there is no data for 938 - inv_turn
# there is no data for 938 - int_totdebt
# there is no data for 938 - 12_month_return
# there is no data for 938 - efftax
# there is no data for 938 - 3_month_return
# there is no data for 938 - intcov
# there is no data for 938 - ocf_lct
# there is no data for 938 - int_debt
# there is no data for 938 - quick_ratio
# there is no data for 938 - rect_act
# there is no data for 938 - invt_act
# there is no data for 938 - dpr
# there is no data for 938 - pretret_noa
# there is no data for 938 - cash_ratio
# there is no data for 938 - curr_debt
# there is no data for 939 - profit_lct
# there is no data for 939 - curr_ratio
# there is no data for 939 - intcov_ratio
# there is no data for 939 - pretret_earnat
# there is no data for 939 - inv_turn
# there is no data for 939 - int_totdebt
# there is no data for 939 - 12_month_return
# there is no data for 939 - efftax
# there is no data for 939 - 3_month_return
# there is no data for 939 - intcov
# there is no data for 939 - ocf_lct
# there is no data for 939 - int_debt
# there is no data for 939 - quick_ratio
# there is no data for 939 - rect_act
# there is no data for 939 - invt_act
# there is no data for 939 - dpr
# there is no data for 939 - pretret_noa
# there is no data for 939 - cash_ratio
# there is no data for 939 - curr_debt
# there is no data for 940 - profit_lct
# there is no data for 940 - curr_ratio
# there is no data for 940 - intcov_ratio

# %%
find_stat_series[data_to_stationarize['profit_lct']]

# %% [markdown]
# # Merge the two dataframes

# %%
data_stat.groupby('divyield').count()['permno']
# Out:
# divyield
# -0.048688     1
# -0.035120     1
# -0.029468     1
# -0.028288     1
# -0.026635     1
#              ..
#  0.292069     1
#  0.295038     1
#  0.301288     1
#  0.302000    41
#  0.527000    21
# Name: permno, Length: 328332, dtype: int64

# %%
data_non_stat['divyield'].unique()
# Out:
# array([0.    , 0.0131, 0.0525, ..., 0.308 , 0.0825, 0.0868])

# %% [markdown]
# # Flag for S&P500

# %%
constituents = pd.read_csv(
    "../../data/sp500_constituents_2010.csv",
    index_col=0,
    parse_dates=["from_date", "thru_date"],
)
constituents.head()
# Out:
#         from_date  thru_date
# permno
# 26825  1961-04-26 2023-12-29
# 46877  1975-06-12 2018-01-02
# 24109  1951-09-06 2023-12-29
# 25320  1957-03-01 2023-12-29
# 70519  1988-05-26 2023-12-29

# %%
# check that the permnos in the two DataFrames are the same
print(set(prices["permno"].unique()) - set(constituents.index.unique()))
print(set(constituents.index.unique()) - set(prices["permno"].unique()))
# Out:
# set()
# set()

# %%
prices["in_sp500"] = 0

permnos = prices["permno"].unique()


def set_in_sp500(permno, from_date, thru_date):
    mask = (
        (prices["permno"] == permno)
        & (prices["date"] >= from_date)
        & (prices["date"] <= thru_date)
    )
    prices.loc[mask, "in_sp500"] = 1


for permno in permnos:

    row = constituents.loc[permno]

    # if there is a single observation process it normally
    if isinstance(row, pd.Series):
        from_date = row.from_date
        thru_date = row.thru_date

        set_in_sp500(permno, from_date, thru_date)

    # if the stock went in and out of the S&P, then process each row separately
    elif isinstance(row, pd.DataFrame):
        for row in row.itertuples():
            from_date = row.from_date
            thru_date = row.thru_date

            set_in_sp500(permno, from_date, thru_date)

# %%
prices.tail()
# Out:
#          permno       date nameendt  shrcd  exchcd  siccd ticker     comnam  \
# 3892525   93436 2023-12-22      NaN     11       3   9999   TSLA  TESLA INC
# 3892526   93436 2023-12-26      NaN     11       3   9999   TSLA  TESLA INC
# 3892527   93436 2023-12-27      NaN     11       3   9999   TSLA  TESLA INC
# 3892528   93436 2023-12-28      NaN     11       3   9999   TSLA  TESLA INC
# 3892529   93436 2023-12-29      NaN     11       3   9999   TSLA  TESLA INC
#
#         tsymbol     naics  ...        mktcap naics_processed industry_return  \
# 3892525    TSLA  336110.0  ...  8.028047e+08            33.0        0.003517
# 3892526    TSLA  336110.0  ...  8.157429e+08            33.0        0.315202
# 3892527    TSLA  336110.0  ...  8.310971e+08            33.0        0.106531
# 3892528    TSLA  336110.0  ...  8.048392e+08            33.0        0.008914
# 3892529    TSLA  336110.0  ...  7.898983e+08            33.0       -0.221914
#
#          industry_relative_return  ret_industry_tot  ret_industry_relative  \
# 3892525                 -0.220480          0.003517              -0.220480
# 3892526                  0.144926          0.315202               0.144926
# 3892527                  0.431040          0.106531               0.431040
# 3892528                 -0.930388          0.008914              -0.930388
# 3892529                 -0.319851         -0.221914              -0.319851
#
#            prc_adj MACD_index        rsi in_sp500
# 3892525  252.53999   4.421230  58.473892        1
# 3892526  256.60999   4.636162  63.398606        1
# 3892527  261.44000   4.915272  68.511971        1
# 3892528  253.17999   5.076989  53.706654        1
# 3892529  248.48000   5.070092  47.033612        1
#
# [5 rows x 70 columns]

# %% [markdown]
# Some sanity checks

# %%
prices["in_sp500"].sum() / prices.shape[0]
# Out:
# 0.6985015602803338
